# %% [markdown]
# # Limpeza e preparação de dados para análise
#
# Este notebook tem a por finalidade a preparação de um DataSet para posterior análise de dados.

# %%
# importando bibliotecas
import pandas as pd
import numpy as np
from summarytools import dfSummary

# %% [markdown]
# ## 1 - Carregando os dados

# %%
# Lendo os dados
open_masc = pd.read_csv('data/women_open_21.1.csv', sep=',', low_memory=False)

# %% [markdown]
# ## 2 - Visualizando dados
# Essa visualização é importante para compreender o que precisa ser feito no dataset.
#
# Verifica-se que algumas colunas de valores estão em string e precisam ser convertidos para numéricos para possibilitar que os calculos sejam feitos.
#
# Há uma coluna que condensa dois dados, peso e altura do atleta, deverá ser convertida em duas colunas.
#
# Há outras colunas que condensam duas informações, por exemplo, a coluna '21.1' armazena dados da posição do atleta naquela prova e também do tempo em que o atleta concluiu a prova. *Vamos ficar apenas com a posição do atleta na prova*.

# %%
# Primeira visualização do Dataframe
open_masc.head()
# Out:
#    Unnamed: 0    first_name   lastname  Placing        country      continent  \
# 0           0     TIA-CLAIR     TOOMEY        1      Australia        Oceania
# 1           1          EMMA       CARY        2  United States  North America
# 2           2          KARA   SAUNDERS        3      Australia        Oceania
# 3           3  KRISTI ERAMO  O'CONNELL        4  United States  North America
# 4           4       MALLORY    O'BRIEN        5  United States  North America
#
#       Age                        affiliate Height and Weight  points  \
# 0  Age 27          CrossFit East Nashville    163 cm | 58 kg      26
# 1  Age 17  Perform Overcome Excel CrossFit    64 in | 140 lb      66
# 2  Age 31                    CrossFit Carv   162 cm | 158 lb     111
# 3  Age 32                 CrossFit Polaris    62 in | 132 lb     189
# 4  Age 17              Lion Brave CrossFit    63 in | 145 lb     211
#
#             21.1 21.1 time           21.2 21.2 time         21.3 21.3 time  \
# 0    6th (11:21)  605 reps    11th (9:26)  225 reps   1st (7:37)  180 reps
# 1   14th (11:48)  605 reps     1st (8:51)  225 reps  14th (8:28)  180 reps
# 2   63rd (13:11)  605 reps    23rd (9:42)  225 reps  20th (8:41)  180 reps
# 3  121st (13:47)  605 reps    21st (9:41)  225 reps   4th (7:47)  180 reps
# 4    4th (11:06)  605 reps  163rd (10:38)  225 reps   2nd (7:38)  180 reps
#
#              21.4                   weight
# 0   8th (230 lbs)  Weight lifted: 230 lbs.
# 1  37th (218 lbs)  Weight lifted: 218 lbs.
# 2   5th (232 lbs)  Weight lifted: 232 lbs.
# 3  43rd (217 lbs)  Weight lifted: 217 lbs.
# 4  42nd (217 lbs)  Weight lifted: 217 lbs.

# %%
# Verificando o "tamanho" do df
open_masc.shape
# Out:
# (108600, 18)

# %%
open_masc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108600 entries, 0 to 108599
# Data columns (total 18 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         108600 non-null  int64
#  1   first_name         108599 non-null  object
#  2   lastname           108597 non-null  object
#  3   Placing            108600 non-null  int64
#  4   country            108600 non-null  object
#  5   continent          108600 non-null  object
#  6   Age                108600 non-null  object
#  7   affiliate          93538 non-null   object
#  8   Height and Weight  50325 non-null   object
#  9   points             108600 non-null  int64
#  10  21.1               108600 non-null  object
#  11  21.1 time          8349 non-null    object
#  12  21.2               108600 non-null  object
#  13  21.2 time          50690 non-null   object
#  14  21.3               108600 non-null  object
#  15  21.3 time          8209 non-null    object
#  16  21.4               108600 non-null  object
#  17  weight             80318 non-null   object
# dtypes: int64(3), object(15)
# memory usage: 14.9+ MB

# %%
# Primeira descrição dos dados numéricos, 
open_masc.describe()
# Out:
#           Unnamed: 0        Placing         points
# count  108600.000000  108600.000000  108600.000000
# mean    54299.500000   54289.647459  211080.913444
# std     31350.263954   31334.182357  107166.944901
# min         0.000000       1.000000      26.000000
# 25%     27149.750000   27150.750000  120400.750000
# 50%     54299.500000   54300.500000  224044.500000
# 75%     81449.250000   81450.250000  303278.250000
# max    108599.000000  108565.000000  374151.000000

# %%
# Verificando quais são as colunas originais do df
open_masc.columns
# Out:
# Index(['Unnamed: 0', 'first_name', 'lastname', 'Placing', 'country',
#        'continent', 'Age', 'affiliate', 'Height and Weight', 'points', '21.1',
#        '21.1 time', '21.2', '21.2 time', '21.3', '21.3 time', '21.4',
#        'weight'],
#       dtype='object')

# %% [markdown]
# ## 3 - Tratando colunas

# %% [markdown]
# ### 3.1 - Renomeando as colunas

# %%
open_masc =  open_masc.rename(columns={'Unnamed: 0': 'index', 'weight': 'weight_lifted', 'Age': 'age', 'Placing':'placing'})

# %% [markdown]
# ### 3.2 - Separando as colunas de altura e peso do atleta
# Ambas as colunas são dados numéricos.
#
# Unidade de de medidas: peso(Kg), altura(cm)

# %% [markdown]
# #### Altura do atleta

# %%
open_masc['height'] = open_masc['Height and Weight']

# %%
def define_height(value):
    x = None
    if type(value) == str:
        a = value.split()
        if a[1] == 'in':
            x = int(a[0]) * 2.54
            x = round(x,2)
        elif a[1] == 'cm':
            x = int(a[0])
            x = round(x,2)
    return x

# %%
open_masc['height'] = open_masc['height'].apply(define_height)

# %% [markdown]
# #### Peso do atleta

# %%
open_masc['weight'] = open_masc['Height and Weight']

# %%
def define_weight(value):
    x = None
    if type(value) == str:
        a = value.split()
        if a[-1] == 'lb':
            x = int(a[-2]) / 2.2
            x = round(x,2)
        elif a[-1] == 'kg':
            x = int(a[-2])
            x = round(x,2)
    return x

# %%
open_masc['weight'] = open_masc['weight'].apply(define_weight)

# %% [markdown]
# Removendo a coluna de peso e altura

# %%
open_masc.drop(['Height and Weight'], axis=1, inplace=True)

# %%
open_masc.head()
# Out:
#    index    first_name   lastname  placing        country      continent  \
# 0      0     TIA-CLAIR     TOOMEY        1      Australia        Oceania
# 1      1          EMMA       CARY        2  United States  North America
# 2      2          KARA   SAUNDERS        3      Australia        Oceania
# 3      3  KRISTI ERAMO  O'CONNELL        4  United States  North America
# 4      4       MALLORY    O'BRIEN        5  United States  North America
#
#       age                        affiliate  points           21.1 21.1 time  \
# 0  Age 27          CrossFit East Nashville      26    6th (11:21)  605 reps
# 1  Age 17  Perform Overcome Excel CrossFit      66   14th (11:48)  605 reps
# 2  Age 31                    CrossFit Carv     111   63rd (13:11)  605 reps
# 3  Age 32                 CrossFit Polaris     189  121st (13:47)  605 reps
# 4  Age 17              Lion Brave CrossFit     211    4th (11:06)  605 reps
#
#             21.2 21.2 time         21.3 21.3 time            21.4  \
# 0    11th (9:26)  225 reps   1st (7:37)  180 reps   8th (230 lbs)
# 1     1st (8:51)  225 reps  14th (8:28)  180 reps  37th (218 lbs)
# 2    23rd (9:42)  225 reps  20th (8:41)  180 reps   5th (232 lbs)
# 3    21st (9:41)  225 reps   4th (7:47)  180 reps  43rd (217 lbs)
# 4  163rd (10:38)  225 reps   2nd (7:38)  180 reps  42nd (217 lbs)
#
#              weight_lifted  height  weight
# 0  Weight lifted: 230 lbs.  163.00   58.00
# 1  Weight lifted: 218 lbs.  162.56   63.64
# 2  Weight lifted: 232 lbs.  162.00   71.82
# 3  Weight lifted: 217 lbs.  157.48   60.00
# 4  Weight lifted: 217 lbs.  160.02   65.91

# %% [markdown]
# ### 3.3 - Transformando a coluna de idade em numérico

# %% [markdown]
# Durante o processo para realizar a transformação da coluna idade (de string para numérico) observou-se inconsistência nos dados da linha 57645, optando-se pela remoção da mesma

# %%
open_masc.iloc[57645]
# Out:
# index                             57645
# first_name                      JESSICA
# lastname                        BALLARD
# placing                           57646
# country                       Australia
# continent                       Oceania
# age                              Age 30
# affiliate            CrossFit Dauntless
# points                           237715
# 21.1                 43056th (179 reps)
# 21.1 time                           NaN
# 21.2                64541st (14:46 - s)
# 21.2 time                      225 reps
# 21.3             59769th (135 reps - s)
# 21.3 time                           NaN
# 21.4               70349th (84 lbs - s)
# weight_lifted    Weight lifted: 84 lbs.
# height                              NaN
# weight                              NaN
# Name: 57645, dtype: object

# %%
open_masc.drop(labels=57645, axis=0, inplace=True, errors='raise')

# %%
def transforma_idade(texto):
    if texto == "":
        x = 0
    else:
        texto.split(" ")
        x = texto[1]
    return(texto[-2:])

# %%
open_masc['age'] = open_masc['age'].apply(transforma_idade)

# %%
# Convertendo a coluna age (idade) de 'string' para numérico
open_masc['age'] = pd.to_numeric(open_masc['age'])

# %% [markdown]
# #### 3.4 - Tratando os resultados das provas

# %%
open_masc = open_masc.drop(labels='21.1 time', axis=1)
open_masc = open_masc.drop(labels='21.2 time', axis=1)
open_masc = open_masc.drop(labels='21.3 time', axis=1)
open_masc.columns
# Out:
# Index(['index', 'first_name', 'lastname', 'placing', 'country', 'continent',
#        'age', 'affiliate', 'points', '21.1', '21.2', '21.3', '21.4',
#        'weight_lifted', 'height', 'weight'],
#       dtype='object')

# %%
# Incluindo texto nos campos nulos de acordo com a coluna
values = {'21.1': '0', '21.2': '0', '21.3': '0', '21.4': '0'}
open_masc.fillna(value = values, inplace=True)

# %%
open_masc.head()
# Out:
#    index    first_name   lastname  placing        country      continent  age  \
# 0      0     TIA-CLAIR     TOOMEY        1      Australia        Oceania   27
# 1      1          EMMA       CARY        2  United States  North America   17
# 2      2          KARA   SAUNDERS        3      Australia        Oceania   31
# 3      3  KRISTI ERAMO  O'CONNELL        4  United States  North America   32
# 4      4       MALLORY    O'BRIEN        5  United States  North America   17
#
#                          affiliate  points           21.1           21.2  \
# 0          CrossFit East Nashville      26    6th (11:21)    11th (9:26)
# 1  Perform Overcome Excel CrossFit      66   14th (11:48)     1st (8:51)
# 2                    CrossFit Carv     111   63rd (13:11)    23rd (9:42)
# 3                 CrossFit Polaris     189  121st (13:47)    21st (9:41)
# 4              Lion Brave CrossFit     211    4th (11:06)  163rd (10:38)
#
#           21.3            21.4            weight_lifted  height  weight
# 0   1st (7:37)   8th (230 lbs)  Weight lifted: 230 lbs.  163.00   58.00
# 1  14th (8:28)  37th (218 lbs)  Weight lifted: 218 lbs.  162.56   63.64
# 2  20th (8:41)   5th (232 lbs)  Weight lifted: 232 lbs.  162.00   71.82
# 3   4th (7:47)  43rd (217 lbs)  Weight lifted: 217 lbs.  157.48   60.00
# 4   2nd (7:38)  42nd (217 lbs)  Weight lifted: 217 lbs.  160.02   65.91

# %%
def define_posicao(p):
    p = p.split(" ")
    x = p[0].strip()
    if ('th' or 'nd' or 'st' or 'rd' in x):
        x = x.replace('th', '')
        x = x.replace('nd', '')
        x = x.replace('st', '')
        x = x.replace('rd', '')
    return x

# %%
open_masc['21.1'] = open_masc['21.1'].apply(define_posicao)
open_masc['21.2'] = open_masc['21.2'].apply(define_posicao)
open_masc['21.3'] = open_masc['21.3'].apply(define_posicao)
open_masc['21.4'] = open_masc['21.4'].apply(define_posicao)
open_masc['21.1'] = pd.to_numeric(open_masc['21.1'])
open_masc['21.2'] = pd.to_numeric(open_masc['21.2'])
open_masc['21.3'] = pd.to_numeric(open_masc['21.3'])
open_masc['21.4'] = pd.to_numeric(open_masc['21.4'])

# %% [markdown]
# ### 3.5 - Transformando a coluna de peso levantado
# Considerando unidade de medida Kg

# %%
open_masc.head()
# Out:
#    index    first_name   lastname  placing        country      continent  age  \
# 0      0     TIA-CLAIR     TOOMEY        1      Australia        Oceania   27
# 1      1          EMMA       CARY        2  United States  North America   17
# 2      2          KARA   SAUNDERS        3      Australia        Oceania   31
# 3      3  KRISTI ERAMO  O'CONNELL        4  United States  North America   32
# 4      4       MALLORY    O'BRIEN        5  United States  North America   17
#
#                          affiliate  points  21.1  21.2  21.3  21.4  \
# 0          CrossFit East Nashville      26     6    11     1   8.0
# 1  Perform Overcome Excel CrossFit      66    14     1    14  37.0
# 2                    CrossFit Carv     111    63    23    20   5.0
# 3                 CrossFit Polaris     189   121    21     4  43.0
# 4              Lion Brave CrossFit     211     4   163     2  42.0
#
#              weight_lifted  height  weight
# 0  Weight lifted: 230 lbs.  163.00   58.00
# 1  Weight lifted: 218 lbs.  162.56   63.64
# 2  Weight lifted: 232 lbs.  162.00   71.82
# 3  Weight lifted: 217 lbs.  157.48   60.00
# 4  Weight lifted: 217 lbs.  160.02   65.91

# %%
# Preenchendo pesos nullos com valor zero, por que considera-se que o atleta não realizou a prova
open_masc['weight_lifted'] = open_masc['weight_lifted'].fillna('0')

# %%
open_masc.tail()
# Out:
#          index first_name lastname  placing         country      continent  \
# 108595  108595   GEORGINA  NOELLEN   108565         Germany         Europe
# 108596  108596     STACEY    MAIDA   108565   United States  North America
# 108597  108597      FIONA    STEEL   108565  United Kingdom         Europe
# 108598  108598    RACHAEL   BUTLER   108565          Canada  North America
# 108599  108599    VALERIA  MONTERO   108565   United States  North America
#
#         age             affiliate  points   21.1   21.2   21.3      21.4  \
# 108595   32        CrossFit Neuss  374151  94308  90537  80806  108500.0
# 108596   36  CrossFit Five Points  374151  94308  90537  80806  108500.0
# 108597   31                   NaN  374151  94308  90537  80806  108500.0
# 108598   34                   NaN  374151  94308  90537  80806  108500.0
# 108599   21                   NaN  374151  94308  90537  80806  108500.0
#
#        weight_lifted  height  weight
# 108595             0   166.0   54.00
# 108596             0   165.1   78.18
# 108597             0     NaN     NaN
# 108598             0     NaN   59.09
# 108599             0   152.4     NaN

# %%
# Iniciando o processo para converter weight_lift para numerico
# Função para remover a string 'lbs' e converter peso para quilos
def substitui_texto(value):
    value = value.replace('Weight lifted: ', '')
    if ('l' in value):
        x = value.replace(' lbs', '')
    elif ('k' in value):
        x = value.replace(' kg', '')
    else:
        x = value
    x = float(x) / 2.205
    
    return(round(x,2))

# %%
#Funaçao para substituir valores inválidos por peso zero
def remove_peso_invalido(value):
    if ('(' in value):
        value = '0'
    return value

# %%
open_masc['weight_lifted'] = open_masc['weight_lifted'].apply(remove_peso_invalido)

# %%
open_masc['weight_lifted'] = open_masc['weight_lifted'].apply(substitui_texto)

# %%
# Convertendo a coluna weight lifted de 'string' para numérico
open_masc['weight_lifted'] = pd.to_numeric(open_masc['weight_lifted'])

# %%
open_masc['weight_lifted']
# Out:
# 0         104.31
# 1          98.87
# 2         105.22
# 3          98.41
# 4          98.41
#            ...
# 108595      0.00
# 108596      0.00
# 108597      0.00
# 108598      0.00
# 108599      0.00
# Name: weight_lifted, Length: 108599, dtype: float64

# %%
import numpy as np

# %%
c = max(open_masc['weight_lifted'])
index = np.where(open_masc['weight_lifted'] == c)
outlier = open_masc.iloc[index]

# %%
print("Nota: O atleta", open_masc['index'].iloc[100332], "apresenta dados inconsistentes referentes ao seu levantamento de peso")
display(outlier)
# Out:
# Nota: O atleta 100333 apresenta dados inconsistentes referentes ao seu levantamento de peso
#        index first_name lastname  placing country continent  age affiliate  \
# 83957  83957       NADA  ELARABY    83958   Egypt    Africa   31       NaN
#
#        points   21.1   21.2   21.3     21.4  weight_lifted  height  weight
# 83957  309900  92052  90537  74680  52631.0        2501.59     NaN     NaN

# %% [markdown]
# ## 4 - Preenchendo missings
# Preencher strings que estão faltando (como nome, país de origem, afiliação, etc). Dadas as características dos dados, optou-se por fazer o preenchimento dos campos que estão vazios ou nullos. Por exemplo, nas colunas referentes ao resultado de uma determinada prova em específico (como a 21.3 ou 21.2) o fato de não ter sido atribuído um valor, indica que o atleta não realizou a prova, portanto atribuiu-se, conforme conveniente, valor zero. Na coluna de afiliação os missings foram tratados como "não afiliados", pois entende-se que se tratam de atletas que treinam em academias próprias ou não afiliada à Crossfit porém que obtiveram o direito de validar suas provas em local licenciado.

# %%
# Conferindo os continentes listados, 
continent = np.array(open_masc['continent'])
unique_continent = np.unique(continent)
print(unique_continent)
# Out:
# ['Africa' 'Asia' 'Europe' 'North America' 'Oceania' 'South America']

# %%
# Visualizando todos os países listados
country = np.array(open_masc['country'])
unique_country = np.unique(country)
print("Total de países participantes: ", len(unique_country))
print(unique_country)
# Out:
# Total de países participantes:  145
# ['Albania' 'Algeria' 'Andorra' 'Angola' 'Antigua and Barbuda' 'Argentina'
#  'Armenia' 'Australia' 'Austria' 'Azerbaijan' 'Bahamas' 'Bahrain'
#  'Bangladesh' 'Barbados' 'Belarus' 'Belgium' 'Belize' 'Bhutan' 'Bolivia'
#  'Bosnia and Herzegovina' 'Botswana' 'Brazil' 'Brunei Darussalam'
#  'Bulgaria' 'Cambodia' 'Cameroon' 'Canada' 'Chile' 'China' 'Colombia'
#  'Costa Rica' 'Croatia' 'Cyprus' 'Czech Republic' 'Denmark'
#  'Dominican Republic' 'Ecuador' 'Egypt' 'El Salvador' 'Estonia' 'Fiji'
#  'Finland' 'France' 'Georgia' 'Germany' 'Ghana' 'Greece' 'Grenada'
#  'Guatemala' 'Guyana' 'Haiti' 'Honduras' 'Hungary' 'Iceland' 'India'
#  'Indonesia' 'Iran' 'Iraq' 'Ireland' 'Israel' 'Italy' 'Jamaica' 'Japan'
#  'Jordan' 'Kazakhstan' 'Kenya' 'Korea, Republic of' 'Kosovo' 'Kuwait'
#  'Latvia' 'Lebanon' 'Libya' 'Liechtenstein' 'Lithuania' 'Luxembourg'
#  'Macedonia' 'Madagascar' 'Malaysia' 'Malta' 'Mauritius' 'Mexico'
#  'Micronesia' 'Moldova' 'Mongolia' 'Montenegro' 'Morocco' 'Mozambique'
#  'Namibia' 'Nepal' 'Netherlands' 'New Zealand' 'Nicaragua' 'Nigeria'
#  'Norway' 'Oman' 'Pakistan' 'Palau' 'Palestinian Territory' 'Panama'
#  'Papua New Guinea' 'Paraguay' 'Peru' 'Philippines' 'Poland' 'Portugal'
#  'Qatar' 'Romania' 'Russian Federation' 'Saint Lucia'
#  'Saint Vincent/Grenadines' 'Samoa' 'Saudi Arabia' 'Senegal' 'Serbia'
#  'Singapore' 'Slovakia' 'Slovenia' 'Solomon Islands' 'South Africa'
#  'Spain' 'Sri Lanka' 'Sudan' 'Suriname' 'Sweden' 'Switzerland'
#  'Syrian Arab Republic' 'Tanzania' 'Thailand' 'Togo' 'Trinidad and Tobago'
#  'Tunisia' 'Turkey' 'Uganda' 'Ukraine' 'United Arab Emirates'
#  'United Kingdom' 'United States' 'Uruguay' 'Uzbekistan' 'Vanuatu'
#  'Venezuela' 'Viet Nam' 'Yemen' 'Zambia' 'Zimbabwe']

# %%
# Verificando onde estão os dados nulos
open_masc.isnull().sum()
# Out:
# index                0
# first_name           1
# lastname             3
# placing              0
# country              0
# continent            0
# age                  0
# affiliate        15062
# points               0
# 21.1                 0
# 21.2                 0
# 21.3                 0
# 21.4                 1
# weight_lifted        0
# height           62867
# weight           62517
# dtype: int64

# %% [markdown]
# A coluna 'first_name' se refere ao primeiro nome do atleta conforme cadastrado no site da Crossfit Games, considerando que apenas um atleta apresenta missing nessa colunas e o atleta possui todos os outros dados consistentes, optou-se por atribuir o valor '-' à essa variável faltante.
#
# A coluna 'last_name' se refere ao sobrenome do atleta conforme cadastrado no site da Crossfit Games, considerando que todos os atletas que não possuem sobrenome cadastrado possuem todos os outros valores consistentes optou-se por preservá-los e atribuir o valor '-' à essa variável faltante.
#
# Os atletas não afiliados recebrão o valor 'not_affiliate' na coluna respectiva
#
# Nota-se que existe um número considerável de atletas cujos dados de peso e altura não foram informados, visando resguardar os outros dados referentes aos resultados dos atletas optou-se por atribuir o valor "uninformed" aos respectivos casos.

# %%
# Encontrando quem tem first_name nulo
open_masc[pd.isna(open_masc['first_name'])]
# Out:
#        index first_name lastname  placing country continent  age  \
# 67999  67999        NaN   ZHUANG    67999   China      Asia   41
#
#            affiliate  points   21.1   21.2   21.3     21.4  weight_lifted  \
# 67999  CrossFit Wusi  269055  59389  74228  63733  71705.0          35.83
#
#        height  weight
# 67999   163.0    55.0

# %%
# Encontrando quem tem lastname nulo
open_masc[pd.isna(open_masc['lastname'])]

# %%
# Incluindo texto nos campos nulos de acordo com a coluna
values = {'lastname': '-', 'first_name': '-', 'affiliate': 'not_affiliate', 'height': 'uninformed', 'weight': 'uninformed'}
open_masc.fillna(value = values, inplace=True)

# %% [markdown]
# ### 4.1 - Convertendo colunas de dados categóricos
# e o indíce em String

# %%
open_masc['continent'] = open_masc['continent'].astype("category")
open_masc['country'] = open_masc['country'].astype("category")
open_masc['affiliate'] = open_masc['affiliate'].astype("category")

# %%
open_masc['index'] = open_masc['index'].astype("str")

# %% [markdown]
# ## 5 - Verificando a qualidade dos dados

# %%
open_masc.isna().sum()
# Nenhum valor null
# Out:
# index            0
# first_name       0
# lastname         0
# placing          0
# country          0
# continent        0
# age              0
# affiliate        0
# points           0
# 21.1             0
# 21.2             0
# 21.3             0
# 21.4             0
# weight_lifted    0
# height           0
# weight           0
# dtype: int64

# %%
# Verificando consistencia dos dados - INCONSISTENTE
# peso_maximo = open_masc['weight_lifted'].max()
# peso_maximo

# %%
dfSummary(open_masc)
# Out:
# <style type="text/css">
# #T_abd07 thead>tr>th {
#   text-align: left;
# }
# #T_abd07_row0_col0, #T_abd07_row1_col0, #T_abd07_row2_col0, #T_abd07_row3_col0, #T_abd07_row4_col0, #T_abd07_row5_col0, #T_abd07_row6_col0, #T_abd07_row7_col0, #T_abd07_row8_col0, #T_abd07_row9_col0, #T_abd07_row10_col0, #T_abd07_row11_col0, #T_abd07_row12_col0, #T_abd07_row13_col0, #T_abd07_row14_col0, #T_abd07_row15_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_abd07_row0_col1, #T_abd07_row1_col1, #T_abd07_row2_col1, #T_abd07_row3_col1, #T_abd07_row4_col1, #T_abd07_row5_col1, #T_abd07_row6_col1, #T_abd07_row7_col1, #T_abd07_row8_col1, #T_abd07_row9_col1, #T_abd07_row10_col1, #T_abd07_row11_col1, #T_abd07_row12_col1, #T_abd07_row13_col1, #T_abd07_row14_col1, #T_abd07_row15_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_abd07_row0_col2, #T_abd07_row1_col2, #T_abd07_row2_col2, #T_abd07_row3_col2, #T_abd07_row4_col2, #T_abd07_row5_col2, #T_abd07_row6_col2, #T_abd07_row7_col2, #T_abd07_row8_col2, #T_abd07_row9_col2, #T_abd07_row10_col2, #T_abd07_row11_col2, #T_abd07_row12_col2, #T_abd07_row13_col2, #T_abd07_row14_col2, #T_abd07_row15_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_abd07_row0_col3, #T_abd07_row1_col3, #T_abd07_row2_col3, #T_abd07_row3_col3, #T_abd07_row4_col3, #T_abd07_row5_col3, #T_abd07_row6_col3, #T_abd07_row7_col3, #T_abd07_row8_col3, #T_abd07_row9_col3, #T_abd07_row10_col3, #T_abd07_row11_col3, #T_abd07_row12_col3, #T_abd07_row13_col3, #T_abd07_row14_col3, #T_abd07_row15_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_abd07_row0_col4, #T_abd07_row1_col4, #T_abd07_row2_col4, #T_abd07_row3_col4, #T_abd07_row4_col4, #T_abd07_row5_col4, #T_abd07_row6_col4, #T_abd07_row7_col4, #T_abd07_row8_col4, #T_abd07_row9_col4, #T_abd07_row10_col4, #T_abd07_row11_col4, #T_abd07_row12_col4, #T_abd07_row13_col4, #T_abd07_row14_col4, #T_abd07_row15_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_abd07_row0_col5, #T_abd07_row1_col5, #T_abd07_row2_col5, #T_abd07_row3_col5, #T_abd07_row4_col5, #T_abd07_row5_col5, #T_abd07_row6_col5, #T_abd07_row7_col5, #T_abd07_row8_col5, #T_abd07_row9_col5, #T_abd07_row10_col5, #T_abd07_row11_col5, #T_abd07_row12_col5, #T_abd07_row13_col5, #T_abd07_row14_col5, #T_abd07_row15_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_abd07">
#   <caption><strong>Data Frame Summary</strong><br>open_masc<br>Dimensions: 137,463 x 16<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_abd07_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_abd07_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_abd07_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_abd07_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_abd07_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_abd07_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_abd07_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_abd07_row0_col1" class="data row0 col1" ><strong>index</strong><br>[object]</td>
#       <td id="T_abd07_row0_col2" class="data row0 col2" >1. 0<br>2. 91638<br>3. 91652<br>4. 91651<br>5. 91650<br>6. 91649<br>7. 91648<br>8. 91647<br>9. 91646<br>10. 91645<br>11. other</td>
#       <td id="T_abd07_row0_col3" class="data row0 col3" >1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>137,453 (100.0%)</td>
#       <td id="T_abd07_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_abd07_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_abd07_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_abd07_row1_col1" class="data row1 col1" ><strong>first_name</strong><br>[object]</td>
#       <td id="T_abd07_row1_col2" class="data row1 col2" >1. MICHAEL<br>2. DAVID<br>3. DANIEL<br>4. CHRIS<br>5. JOHN<br>6. RYAN<br>7. JASON<br>8. MATTHEW<br>9. ANDREW<br>10. JAMES<br>11. other</td>
#       <td id="T_abd07_row1_col3" class="data row1 col3" >2,226 (1.6%)<br>1,995 (1.5%)<br>1,575 (1.1%)<br>1,486 (1.1%)<br>1,385 (1.0%)<br>1,365 (1.0%)<br>1,278 (0.9%)<br>1,246 (0.9%)<br>1,224 (0.9%)<br>1,184 (0.9%)<br>122,499 (89.1%)</td>
#       <td id="T_abd07_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_abd07_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_abd07_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_abd07_row2_col1" class="data row2 col1" ><strong>lastname</strong><br>[object]</td>
#       <td id="T_abd07_row2_col2" class="data row2 col2" >1. SMITH<br>2. LEE<br>3. JOHNSON<br>4. JONES<br>5. KIM<br>6. BROWN<br>7. WILLIAMS<br>8. GARCIA<br>9. MILLER<br>10. WILSON<br>11. other</td>
#       <td id="T_abd07_row2_col3" class="data row2 col3" >713 (0.5%)<br>394 (0.3%)<br>392 (0.3%)<br>388 (0.3%)<br>384 (0.3%)<br>368 (0.3%)<br>330 (0.2%)<br>318 (0.2%)<br>312 (0.2%)<br>271 (0.2%)<br>133,593 (97.2%)</td>
#       <td id="T_abd07_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_abd07_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_abd07_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_abd07_row3_col1" class="data row3 col1" ><strong>placing</strong><br>[object]</td>
#       <td id="T_abd07_row3_col2" class="data row3 col2" >1. 135018<br>2. 132082<br>3. 121767<br>4. 127322<br>5. 125679<br>6. 134099<br>7. 136916<br>8. 128150<br>9. 123553<br>10. 131081<br>11. other</td>
#       <td id="T_abd07_row3_col3" class="data row3 col3" >852 (0.6%)<br>595 (0.4%)<br>591 (0.4%)<br>450 (0.3%)<br>401 (0.3%)<br>380 (0.3%)<br>378 (0.3%)<br>378 (0.3%)<br>363 (0.3%)<br>353 (0.3%)<br>132,722 (96.6%)</td>
#       <td id="T_abd07_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_abd07_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_abd07_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_abd07_row4_col1" class="data row4 col1" ><strong>country</strong><br>[category]</td>
#       <td id="T_abd07_row4_col2" class="data row4 col2" >1. United States<br>2. Australia<br>3. United Kingdom<br>4. France<br>5. Canada<br>6. Brazil<br>7. Spain<br>8. South Africa<br>9. Germany<br>10. Sweden<br>11. other</td>
#       <td id="T_abd07_row4_col3" class="data row4 col3" >65,145 (47.4%)<br>8,206 (6.0%)<br>6,080 (4.4%)<br>6,038 (4.4%)<br>5,321 (3.9%)<br>4,994 (3.6%)<br>4,844 (3.5%)<br>3,152 (2.3%)<br>2,705 (2.0%)<br>2,138 (1.6%)<br>28,840 (21.0%)</td>
#       <td id="T_abd07_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_abd07_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_abd07_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_abd07_row5_col1" class="data row5 col1" ><strong>continent</strong><br>[category]</td>
#       <td id="T_abd07_row5_col2" class="data row5 col2" >1. North America<br>2. Europe<br>3. Oceania<br>4. Asia<br>5. South America<br>6. Africa</td>
#       <td id="T_abd07_row5_col3" class="data row5 col3" >73,659 (53.6%)<br>34,317 (25.0%)<br>9,930 (7.2%)<br>8,194 (6.0%)<br>7,076 (5.1%)<br>4,287 (3.1%)</td>
#       <td id="T_abd07_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_abd07_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_abd07_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_abd07_row6_col1" class="

# %%
#Salvando o dataframe para análise
open_masc.to_csv("data/crossfit_open_feminino_2021.csv")
